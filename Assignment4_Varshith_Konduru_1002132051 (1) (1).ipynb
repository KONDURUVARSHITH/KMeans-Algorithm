# %% [markdown]
# #CSE 5334, Falll 2023, University of Texas at Arlington
# #  Clustering
#
#
# ## **Academic Honesty**
# This assignment must be done individually and independently. You must implement the whole assignment by yourself. Academic dishonesty is not tolerated.
#
# ## **Requirements**
#
# 1.   When you work on this assignment, you should make a copy of this notebook in Google Colab. This can be done using the option `File > Save a copy in Drive` in Google Colab.
#
# 2.  To submit your assignment, download your Colab into a .ipynb file. This
# can be done using the option `Download > Download .ipynb` in Google Colab. Submit the downloaded .ipynb file/ .zip into the Programming Assignment 4 entry in Canvas.

# %% [markdown]
# ## **Description**
#
# Iris Data Set:
# A dataset containing information about different types of flowers. Each flower is described using four features - sepal length, sepal width, petal length, and petal width. The dataset contains 150 samples, with 50 samples for each of the three species of flowers - Iris setosa, Iris virginica, and Iris versicolor.

# %% [markdown]
# ## **Tasks to Code**
# 1.  Load the dataset using Python libraries such as Pandas and Numpy.
# 2.   Visualize the dataset using scatter plots to see if there are any natural clusters in the data.
# 3. Preprocess the data by scaling it to ensure that all the features are on the same scale.
# 4.Use the KMeans algorithm to cluster the data into three clusters, one for each type of flower.
# 5.  Visualize the clusters using scatter plots and color-coding to see how well the algorithm was able to separate the different types of flowers.
# 6. Evaluate the quality of the clustering using metrics such as the silhouette score.
# 7.  Experiment with different values of K (the number of clusters) to see how it affects the quality of the clustering.
# 8.   Implement hierarchical clustering and compare the results with KMeans.

# %% [markdown]
# Task 1: Load the dataset using Python libraries such as Pandas and Numpy.

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith imported all the required libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith mounted the Drive using drive.mount()
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith read the KNN_Data excel file to vars_data using Pandas
x="/content/drive/MyDrive/Colab Notebooks/iris.csv"
vars_data=pd.read_csv(x)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith displayed the head of the vars_data dataframe using head()
vars_data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith read the iris.csv using pandas and assisned to vars_data1
vars_data1=pd.read_csv(x)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith read the iris.csv using pandas and assisned to vars_data2
vars_data2=pd.read_csv(x)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith read the iris.csv using pandas and assisned to vars_data_d
vars_data_d=pd.read_csv(x)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith read the iris.csv using pandas and assisned to vars_datah
vars_datah=pd.read_csv(x)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith read the iris.csv using pandas and assisned to vars_datah_2
vars_datah_2=pd.read_csv(x)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith read the iris.csv using pandas and assisned to vars_datah_5
vars_datah_5=pd.read_csv(x)

# %% [markdown]
# Task 2: Visualize the dataset using scatter plots to see if there are any natural clusters in the data.<br>
#
# Scatter Plot Matrix:

# %%
# Varshith Konduru(1002132051)
# My Individual Project


# Varshith using pairplot() in seaborn libraries to plot large pairplot
vars_plot= sns.pairplot(vars_data, hue='variety')

# Varshith included steps in Histogram
vars_plot.map_diag(sns.histplot, element="step")

# Varshith display the plot
plt.show()

# %% [markdown]
# # Observation of above graph.
#
# I utilized a pair plot, which is also known as a scatter plot matrix, to comprehensively visualize the relationships between all pairs of features in iris.csv. We can observe that, there are some clusters formed but it didn't form efficiently. For instance, as you can see scatter plot between sepal.width and sepal.length, we can see that blue dots(setosa) cluster is formed effeciently but orange(versicolor) and green(virginica) clusters overlaps eachother. Similary, in all other scatter plots, we can see clusters are formed but need further analysis to enhance the clusters.

# %% [markdown]
# Task 3: Preprocess the data by scaling it to ensure that all the features are on the same scale.

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith imported StandardScaler from sklearn.preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith created vars_scaler object using StandardScaler() we imported from above
vars_scaler = StandardScaler()

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith is dropping variety as we want only the features of the dataset
apple= vars_data.drop('variety', axis=1)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith used standard scaling to all the features and used fit_tranform() and assigned it to vars_scaled_feat
vars_scaled_feat = vars_scaler.fit_transform(apple)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned the scaled features to vars_dataframe
vars_dataframe = pd.DataFrame(vars_scaled_feat, columns=vars_data.columns[:-1])

# Varshith displayed head of vars_dataframe
vars_dataframe.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444

# %% [markdown]
# Tsk 4: Use the KMeans algorithm to cluster the data into three clusters, one for each type of flower.

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varsith created vars_kmeans with KMeans clustering with the n_clusters=3
vars_kmeans = KMeans(n_clusters=3, random_state=44)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith fitted vars_kmeans to vars_scaled_feat
vars_kmeans.fit(vars_scaled_feat)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=44)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned cluster labels to the data points.
vars_cluster_labels = vars_kmeans.labels_

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith added cluster labels to vars_data
vars_data['KmeansCluster'] = vars_cluster_labels.copy()

# Varshith displayed the vars_data
print(vars_data)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      KmeansCluster
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith displayed the top 5 data of vars_data
vars_data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  KmeansCluster
# 0           5.1          3.5           1.4          0.2  Setosa              1
# 1           4.9          3.0           1.4          0.2  Setosa              1
# 2           4.7          3.2           1.3          0.2  Setosa              1
# 3           4.6          3.1           1.5          0.2  Setosa              1
# 4           5.0          3.6           1.4          0.2  Setosa              1

# %% [markdown]
# Task 5: Visualize the clusters using scatter plots and color-coding to see how well the algorithm was able to separate the different types of flowers.

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith using pairplot() in seaborn libraries to plot large pairplot with hue="KmeansCluster"
sns.pairplot(vars_data, hue="KmeansCluster", palette="deep", markers=["v", "o", "s"])

# Varshith displayed the plot
plt.show()

# %% [markdown]
# # Observation of above graph.
#
# I utilized a pair plot, which is also known as a scatter plot matrix, to comprehensively visualize the relationships between all pairs of features in iris.csv. We can observe that, there are some clusters formed form efficiently. For instance, as you can see scatter plot between sepal.width and sepal.length, we can see that blue dots(setosa) cluster is formed effeciently and orange(versicolor) and green(virginica) clusters also formed with good formation. Similary, in all other scatter plots, we can see clusters are formed but there can be further analysis to enhance the clusters.

# %% [markdown]
# Task 6: Evaluate the quality of the clustering using metrics such as the silhouette score.

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith imported silhouette_score from from sklearn.metrics
from sklearn.metrics import silhouette_score

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith calculated silhouette_score and assigned to vars_silhouette_score
vars_silhouette_score = silhouette_score(vars_scaled_feat, vars_kmeans.labels_)

# Varshith Printed vars_silhouette_score
print(f"Silhouette_Score: {vars_silhouette_score}")
# Out:
# Silhouette_Score: 0.45994823920518646

# %% [markdown]
# Task 7: Experiment with different values of K (the number of clusters) to see how it affects the quality of the clustering.

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith imported StandardScaler from sklearn.preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith created vars_scaler object using StandardScaler() we imported from above
vars_scaler = StandardScaler()

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith is dropping variety as we want only the features of the dataset
apple= vars_data1.drop('variety', axis=1)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith used standard scaling to all the features and used fit_tranform() and assigned it to vars_scaled_feat
vars_scaled_feat = vars_scaler.fit_transform(apple)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varsith created vars_kmeans_5 with KMeans clustering with the n_clusters=5
vars_kmeans_5 = KMeans(n_clusters=5, random_state=44)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith fitted vars_kmeans_5 to vars_scaled_feat
vars_kmeans_5.fit(vars_scaled_feat)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=44)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned cluster labels to the data points.
vars_cluster_labels_5 = vars_kmeans_5.labels_

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith added vars_cluster_labels_5 to vars_data1
vars_data1['KmeansCluster_5'] = vars_cluster_labels_5

# Varshith displayed the vars_data1
print(vars_data1)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      KmeansCluster_5
# 0                  0
# 1                  4
# 2                  4
# 3                  4
# 4                  0
# ...

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith displayed the top 5 data of vars_data1
vars_data1.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  \
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
#
#    KmeansCluster_5
# 0                0
# 1                4
# 2                4
# 3                4
# 4                0

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith using pairplot() in seaborn libraries to plot large pairplot with hue="KmeansCluster_5"
sns.pairplot(vars_data1, hue="KmeansCluster_5", palette="deep", markers=["v", "o", "s", "d","p"])

# Varshith displayed the plot
plt.show()

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith calculated silhouette_score and assigned to vars_silhouette_score
vars_silhouette_score = silhouette_score(vars_scaled_feat, vars_kmeans_5.labels_)

# Varshith Printed vars_silhouette_score
print(f"Silhouette_Score: {vars_silhouette_score}")
# Out:
# Silhouette_Score: 0.3459012795948778

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varsith created vars_kmeans_2 with KMeans clustering with the n_clusters=2
vars_kmeans_2 = KMeans(n_clusters=2, random_state=44)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith fitted vars_kmeans_2 to vars_scaled_feat
vars_kmeans_2.fit(vars_scaled_feat)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2, random_state=44)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned cluster labels to the data points.
vars_cluster_labels_2 = vars_kmeans_2.labels_

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith added vars_cluster_labels_2 to vars_data2
vars_data2['KmeansCluster_2'] = vars_cluster_labels_2

# Varshith displayed the vars_data2
print(vars_data2)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      KmeansCluster_2
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith displayed the top 5 data of vars_data2
vars_data2.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  \
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
#
#    KmeansCluster_2
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith using pairplot() in seaborn libraries to plot large pairplot with hue="KmeansCluster_2"
sns.pairplot(vars_data2, hue="KmeansCluster_2", palette="deep", markers=["v", "o"])

# Varshith displayed the plot
plt.show()

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith calculated silhouette_score and assigned to vars_silhouette_score
vars_silhouette_score = silhouette_score(vars_scaled_feat, vars_kmeans_2.labels_)

# Varshith Printed vars_silhouette_score
print(f"Silhouette_Score: {vars_silhouette_score}")
# Out:
# Silhouette_Score: 0.5817500491982808

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned vars_k with range(2, 20)
vars_k = range(2, 27)

# Varshith assigned vars_silhouette with empty list
vars_silhouette = []

# Varshith used for loop to find Silhouette Score for all the values in vars_k
for val in vars_k:
   vars_kmeans = KMeans(n_clusters=val, n_init=10, random_state=44)     # Varsith created vars_kmeans with KMeans clustering with the n_clusters=val, n_init=10, random_state=44
   vars_kmeans.fit(vars_scaled_feat)                                    # Varshith fitted vars_kmeans to vars_scaled_feat

   # Varshith computed silhouette_score
   vars_score_s= silhouette_score(vars_scaled_feat, vars_kmeans.labels_)
   vars_silhouette.append(vars_score_s)

  # Varshith printed the output
   print(f"Silhouette Score with {val} clusters for Kmeans clustering: {vars_score_s}")
# Out:
# Silhouette Score with 2 clusters for Kmeans clustering: 0.5817500491982808
# Silhouette Score with 3 clusters for Kmeans clustering: 0.45994823920518646
# Silhouette Score with 4 clusters for Kmeans clustering: 0.38517417630641415
# Silhouette Score with 5 clusters for Kmeans clustering: 0.3459012795948778
# Silhouette Score with 6 clusters for Kmeans clustering: 0.3229211956956453
# Silhouette Score with 7 clusters for Kmeans clustering: 0.3489366991453436
# Silhouette Score with 8 clusters for Kmeans clustering: 0.3311639699677482
# Silhouette Score with 9 clusters for Kmeans clustering: 0.337139137102521
# Silhouette Score with 10 clusters for Kmeans clustering: 0.3490059453634318
# Silhouette Score with 11 clusters for Kmeans clustering: 0.3515844113413361
# Silhouette Score with 12 clusters for Kmeans clustering: 0.3471916790835647
# Silhouette Score with 13 clusters for Kmeans clustering: 0.3602000337018492
# ...

# %% [markdown]
# Task 8: Implement hierarchical clustering and compare the results with KMeans.

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith imported StandardScaler from sklearn.preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith created vars_scaler object using StandardScaler() we imported from above
vars_scaler1 = StandardScaler()

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith used standard scaling to all the features and used fit_tranform() and assigned it to vars_scaled_feat1
vars_scaled_feat1 = vars_scaler1.fit_transform(vars_data_d.drop('variety', axis=1))

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned the scaled features to vars_dataframe1
vars_d = pd.DataFrame(vars_scaled_feat1, columns=vars_data_d.columns[:-1])

# Varshith displayed head of vars_dataframe
vars_d.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith imported AgglomerativeClustering from sklearn.cluster
from sklearn.cluster import AgglomerativeClustering

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varsith created vars_hierar_clust with Hierarchical clustering with the n_clusters=3
vars_hierar_clust = AgglomerativeClustering(n_clusters=3)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith fitted hierar_labels to vars_scaled_feat1
hierar_labels = vars_hierar_clust.fit_predict(vars_scaled_feat1)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned hierar_labels to vars_datah dataframe
vars_datah['Hierarchical_Cluster_3'] = hierar_labels

# %%
# Varshith displayed the vars_datah
print(vars_datah)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      Hierarchical_Cluster_3
# 0                         1
# 1                         1
# 2                         1
# ...

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith imported silhouette_score from from sklearn.metrics
from sklearn.metrics import silhouette_score

# Varshith calculated silhouette_score and assigned to vars_silhouette_score
vars_silhouette_score = silhouette_score(vars_scaled_feat1, hierar_labels)

# Varshith Printed vars_silhouette_score
print(f"Silhouette_Score: {vars_silhouette_score}")
# Out:
# Silhouette_Score: 0.446689041028591

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith using pairplot() in seaborn libraries to plot large pairplot with hue="Hierarchical_Cluster_3"
sns.pairplot(vars_datah, hue="Hierarchical_Cluster_3", palette="deep", markers=["v", "o","p"])

# Varshith displayed the plot
plt.show()

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith imported AgglomerativeClustering from sklearn.cluster
from sklearn.cluster import AgglomerativeClustering

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varsith created vars_hierar_clust with Hierarchical clustering with the n_clusters=2
vars_hierar_clust = AgglomerativeClustering(n_clusters=2)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith fitted hierar_labels to vars_scaled_feat1
hierar_labels = vars_hierar_clust.fit_predict(vars_scaled_feat1)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith fitted hierar_labels to vars_scaled_feat1
hierar_labels = vars_hierar_clust.fit_predict(vars_scaled_feat1)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned hierar_labels to vars_datah_2 dataframe
vars_datah_2['Hierarchical_Cluster_2'] = hierar_labels

# %%
# Varshith displayed the vars_datah_2
print(vars_datah_2)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      Hierarchical_Cluster_2
# 0                         1
# 1                         1
# 2                         1
# ...

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith calculated silhouette_score and assigned to vars_silhouette_score
vars_silhouette_score = silhouette_score(vars_scaled_feat1, hierar_labels)

# Varshith Printed vars_silhouette_score
print(f"Silhouette_Score: {vars_silhouette_score}")
# Out:
# Silhouette_Score: 0.5770346019475988

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith using pairplot() in seaborn libraries to plot large pairplot with hue="Hierarchical_Cluster_2"
sns.pairplot(vars_datah_2, hue="Hierarchical_Cluster_2", palette="deep", markers=["v", "o"])

# Varshith displayed the plot
plt.show()

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varsith created vars_hierar_clust with Hierarchical clustering with the n_clusters=5
vars_hierar_clust = AgglomerativeClustering(n_clusters=5)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith fitted hierar_labels to vars_scaled_feat
hierar_labels = vars_hierar_clust.fit_predict(vars_scaled_feat1)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith fitted hierar_labels to vars_scaled_feat
hierar_labels = vars_hierar_clust.fit_predict(vars_scaled_feat1)

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned hierar_labels to vars_datah_5 dataframe
vars_datah_5['Hierarchical_Cluster_5'] = hierar_labels

# %%
# Varshith displayed the vars_datah_5
print(vars_datah_5)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      Hierarchical_Cluster_5
# 0                         2
# 1                         4
# 2                         4
# ...

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith calculated silhouette_score and assigned to vars_silhouette_score
vars_silhouette_score = silhouette_score(vars_scaled_feat1, hierar_labels)

# Varshith Printed vars_silhouette_score
print(f"Silhouette_Score: {vars_silhouette_score}")
# Out:
# Silhouette_Score: 0.33058726295230545

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith using pairplot() in seaborn libraries to plot large pairplot with hue="Hierarchical_Cluster_5"
sns.pairplot(vars_datah_5, hue="Hierarchical_Cluster_5", palette="deep", markers=["v", "o","s","p","d"])

# Varshith displayed the plot
plt.show()

# %%
# Varshith Konduru(1002132051)
# My Individual Project

# Varshith assigned vars_k with range(2, 20)
vars_k = range(2, 27)

# Varshith assigned vars_silhouette with empty list
vars_silhouette = []

# Varshith used for loop to find Silhouette Score for all the values in vars_k
for val in vars_k:
   vars_h = AgglomerativeClustering(n_clusters=val)     # Varsith created vars_h with Hierachical clustering with the n_clusters=val, n_init=10, random_state=44
   vars_h.fit(vars_scaled_feat1)                                    # Varshith fitted vars_h to vars_scaled_feat

   # Varshith computed silhouette_score
   vars_score_s= silhouette_score(vars_scaled_feat1, vars_h.labels_)
   vars_silhouette.append(vars_score_s)

  # Varshith printed the output
   print(f"Silhouette Score with {val} clusters for Hierarchical clustering: {vars_score_s}")
# Out:
# Silhouette Score with 2 clusters for Hierarchical clustering: 0.5770346019475988
# Silhouette Score with 3 clusters for Hierarchical clustering: 0.446689041028591
# Silhouette Score with 4 clusters for Hierarchical clustering: 0.40063631598559735
# Silhouette Score with 5 clusters for Hierarchical clustering: 0.33058726295230545
# Silhouette Score with 6 clusters for Hierarchical clustering: 0.31485480100512825
# Silhouette Score with 7 clusters for Hierarchical clustering: 0.31696983029912795
# Silhouette Score with 8 clusters for Hierarchical clustering: 0.31094652900725794
# Silhouette Score with 9 clusters for Hierarchical clustering: 0.31143422475471655
# Silhouette Score with 10 clusters for Hierarchical clustering: 0.3161120375980681
# Silhouette Score with 11 clusters for Hierarchical clustering: 0.29900644634706536
# Silhouette Score with 12 clusters for Hierarchical clustering: 0.3050717010768743
# ...

# %% [markdown]
# # Comparision between K-means Clustering and Hierarchical Clustering:
#
# Kmeans Clustering: vars_kmeans = KMeans(n_clusters=3, random_state=44):
# For n_clusters=3 we get Silhouette_Score: 0.45994823920518646.<br>
# Hierarchical Clustering:vars_hierar_clust = AgglomerativeClustering(n_clusters=3): we don't have random state parameter in Hierachical Clustering since it is deterministic process.
# For n_clusters=3 we get Silhouette_Score: 0.446689041028591.<br>
# We know that if Silhouette_Score=1 then it is good clustering, so from above Silhouette_Score we can observe that Kmeans Clustering is near to 1, so we can conclude that Kmeans Clustering is good clustering for n_clusters=3.<br>
# <br>
#
# Kmeans Clustering:vars_kmeans_5 = KMeans(n_clusters=5, random_state=44):
# For n_clusters=5 we get Silhouette_Score: 0.3459012795948778.<br>
# Hierarchical Clustering:vars_hierar_clust = AgglomerativeClustering(n_clusters=5): we don't have random state parameter in Hierachical Clustering since it is deterministic process. For n_clusters=5 we get Silhouette_Score: 0.33058726295230545.<br>
# We know that if Silhouette_Score=1 then it is good clustering, so from above Silhouette_Score we can observe that Kmeans Clustering is near to 1, so we can conclude that Kmeans Clustering is good clustering for n_clusters=5.<br>
# <br>
#
# Different Silhouette_score for Kmeans Clustering for different n_clusters values:<br>
# Silhouette Score with 2 clusters for Kmeans clustering: 0.5817500491982808 <br>
# Silhouette Score with 3 clusters for Kmeans clustering: 0.45994823920518646<br>
# Silhouette Score with 4 clusters for Kmeans clustering: 0.38517417630641415<br>
# Silhouette Score with 5 clusters for Kmeans clustering: 0.3459012795948778<br>
# Silhouette Score with 6 clusters for Kmeans clustering: 0.3229211956956453<br>
# Silhouette Score with 7 clusters for Kmeans clustering: 0.3489366991453436<br>
# Silhouette Score with 8 clusters for Kmeans clustering: 0.3311639699677482<br>
# Silhouette Score with 9 clusters for Kmeans clustering: 0.337139137102521<br>
# Silhouette Score with 10 clusters for Kmeans clustering: 0.3490059453634318<br>
# Silhouette Score with 11 clusters for Kmeans clustering: 0.3515844113413361<br>
# Silhouette Score with 12 clusters for Kmeans clustering: 0.3471916790835647<br>
# Silhouette Score with 13 clusters for Kmeans clustering: 0.3602000337018492<br>
# Silhouette Score with 14 clusters for Kmeans clustering: 0.33772724584401126<br>
# Silhouette Score with 15 clusters for Kmeans clustering: 0.33227998100248013<br>
# Silhouette Score with 16 clusters for Kmeans clustering: 0.31912980618296816<br>
# Silhouette Score with 17 clusters for Kmeans clustering: 0.3391347572550051<br>
# Silhouette Score with 18 clusters for Kmeans clustering: 0.3239666682634256<br>
# Silhouette Score with 19 clusters for Kmeans clustering: 0.3003561286409765<br>
# Silhouette Score with 20 clusters for Kmeans clustering: 0.3035416716790659<br>
# Silhouette Score with 21 clusters for Kmeans clustering: 0.31843886226151086<br>
# Silhouette Score with 22 clusters for Kmeans clustering: 0.31257284192437984<br>
# Silhouette Score with 23 clusters for Kmeans clustering: 0.2968095622078907<br>
# Silhouette Score with 24 clusters for Kmeans clustering: 0.2932439672866362<br>
# Silhouette Score with 25 clusters for Kmeans clustering: 0.3006720035911788<br>
# Silhouette Score with 26 clusters for Kmeans clustering: 0.2887378569860245<br><br>
#
# Different Silhouette_score for Hierarchical Clustering for different n_clusters values:<br>
# Silhouette Score with 2 clusters for Hierarchical clustering: 0.5770346019475988
# <br>Silhouette Score with 3 clusters for Hierarchical clustering: 0.446689041028591<br>
# Silhouette Score with 4 clusters for Hierarchical clustering: 0.40063631598559735<br>
# Silhouette Score with 5 clusters for Hierarchical clustering: 0.33058726295230545<br>
# Silhouette Score with 6 clusters for Hierarchical clustering: 0.31485480100512825<br>
# Silhouette Score with 7 clusters for Hierarchical clustering: 0.31696983029912795<br>
# Silhouette Score with 8 clusters for Hierarchical clustering: 0.31094652900725794<br>
# Silhouette Score with 9 clusters for Hierarchical clustering: 0.31143422475471655<br>
# Silhouette Score with 10 clusters for Hierarchical clustering: 0.3161120375980681<br>
# Silhouette Score with 11 clusters for Hierarchical clustering: 0.29900644634706536<br>
# Silhouette Score with 12 clusters for Hierarchical clustering: 0.3050717010768743<br>
# Silhouette Score with 13 clusters for Hierarchical clustering: 0.31729733710109526<br>
# Silhouette Score with 14 clusters for Hierarchical clustering: 0.3165285044481548<br>
# Silhouette Score with 15 clusters for Hierarchical clustering: 0.32028947421165554<br>
# Silhouette Score with 16 clusters for Hierarchical clustering: 0.3279256494442729<br>
# Silhouette Score with 17 clusters for Hierarchical clustering: 0.3294684159739696<br>
# Silhouette Score with 18 clusters for Hierarchical clustering: 0.30868352719401204<br>
# Silhouette Score with 19 clusters for Hierarchical clustering: 0.3102549484075962<br>
# Silhouette Score with 20 clusters for Hierarchical clustering: 0.2918311233196793<br>
# Silhouette Score with 21 clusters for Hierarchical clustering: 0.2874678957320372<br>
# Silhouette Score with 22 clusters for Hierarchical clustering: 0.2903354707846748<br>
# Silhouette Score with 23 clusters for Hierarchical clustering: 0.2887273375706796<br>
# Silhouette Score with 24 clusters for Hierarchical clustering: 0.28915606326156434<br>
# Silhouette Score with 25 clusters for Hierarchical clustering: 0.28337767341661896<br>
# Silhouette Score with 26 clusters for Hierarchical clustering: 0.2837202953442633<br>
